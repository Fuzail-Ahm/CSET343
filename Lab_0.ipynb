# %%
# Lab Assignment 0
# CSET343 - AI in Healthcare

print("Hello, AI in Healthcare!")
# Out:
# Hello, AI in Healthcare!

# %%
# Writing to a file

with open("patient_data.txt", "w") as file:
    file.write("Patient ID: P001\n")
    file.write("Age: 45\n")
    file.write("Disease: Heart Disease\n")

print("File created successfully!")
# Out:
# File created successfully!

# %%
# Reading from a file

with open("patient_data.txt", "r") as file:
    data = file.read()

print(data)
# Out:
# Patient ID: P001
# Age: 45
# Disease: Heart Disease

# %%
import pandas as pd

# Creating sample patient data

patient_data = {
    "Patient_ID": ["P001", "P002", "P003", "P004"],
    "Age": [45, 52, 38, 61],
    "Blood_Pressure": [130, 145, 120, 150],
    "Cholesterol": [220, 250, 190, 270]
}

df = pd.DataFrame(patient_data)

print(df)
# Out:
#   Patient_ID  Age  Blood_Pressure  Cholesterol
# 0       P001   45             130          220
# 1       P002   52             145          250
# 2       P003   38             120          190
# 3       P004   61             150          270

# %%
# Basic DataFrame operations

print("First 2 rows:")
print(df.head(2))

print("\nData information:")
print(df.info())

print("\nStatistical summary:")
print(df.describe())
# Out:
# First 2 rows:
#   Patient_ID  Age  Blood_Pressure  Cholesterol
# 0       P001   45             130          220
# 1       P002   52             145          250
#
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      4 non-null      object
#  1   Age             4 non-null      int64
#  2   Blood_Pressure  4 non-null      int64
#  3   Cholesterol     4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes
# None
#
# Statistical summary:
#              Age  Blood_Pressure  Cholesterol
# count   4.000000        4.000000          4.0
# mean   49.000000      136.250000        232.5
# std     9.831921       13.768926         35.0
# min    38.000000      120.000000        190.0
# 25%    43.250000      127.500000        212.5
# 50%    48.500000      137.500000        235.0
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.bar(df["Patient_ID"], df["Age"])

plt.xlabel("Patient ID")
plt.ylabel("Age")
plt.title("Patient Age Distribution")

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.plot(df["Patient_ID"], df["Cholesterol"], marker="o")

plt.xlabel("Patient ID")
plt.ylabel("Cholesterol")
plt.title("Patient Cholesterol Levels")

plt.show()
